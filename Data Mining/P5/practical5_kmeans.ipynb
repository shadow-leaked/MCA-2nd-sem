# %% [markdown]
# # Practical 5
# # K-Means Clustering

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
data = {
    'x': [1,2,3,10,11,12,25,26,27],
    'y': [1,2,3,10,11,12,25,26,27]
}

# %%
df = pd.DataFrame(data)

print(df)
# Out:
#     x   y
# 0   1   1
# 1   2   2
# 2   3   3
# 3  10  10
# 4  11  11
# 5  12  12
# 6  25  25
# 7  26  26
# 8  27  27

# %%
kmeans = KMeans(n_clusters=3, random_state=1)

# %%
kmeans.fit(df)
# Out:
# KMeans(n_clusters=3, random_state=1)

# %%
print("Cluster Labels")
print(kmeans.labels_)
# Out:
# Cluster Labels
# [2 2 2 0 0 0 1 1 1]

# %%
plt.scatter(df['x'], df['y'], c=kmeans.labels_)
plt.xlabel("X")
plt.ylabel("Y")
plt.title("K-Means Clustering")
plt.show()

# %% [markdown]
# ## Conclusion
#
# K-Means successfully grouped similar data into clusters.
