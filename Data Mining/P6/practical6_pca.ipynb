# %% [markdown]
# # Practical 6
# # PCA Dimensionality Reduction

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
data = {
    'A': [1,2,None,4,5],
    'B': [5,4,3,2,1],
    'C': [2,3,4,5,6]
}

# %%
df = pd.DataFrame(data)

print(df)
# Out:
#      A  B  C
# 0  1.0  5  2
# 1  2.0  4  3
# 2  NaN  3  4
# 3  4.0  2  5
# 4  5.0  1  6

# %%
df.fillna(df.mean(), inplace=True)

print("After Handling Missing Values")
print(df)
# Out:
# After Handling Missing Values
#      A  B  C
# 0  1.0  5  2
# 1  2.0  4  3
# 2  3.0  3  4
# 3  4.0  2  5
# 4  5.0  1  6

# %%
scaler = StandardScaler()

scaled_data = scaler.fit_transform(df)

# %%
pca = PCA(n_components=2)

# %%
result = pca.fit_transform(scaled_data)

# %%
print("PCA Result")
print(result)
# Out:
# PCA Result
# [[-2.44948974e+00 -2.03908411e-16]
#  [-1.22474487e+00  6.79694702e-17]
#  [ 0.00000000e+00  0.00000000e+00]
#  [ 1.22474487e+00 -6.79694702e-17]
#  [ 2.44948974e+00 -1.35938940e-16]]

# %% [markdown]
# ## Conclusion
#
# Data preprocessing and dimensionality reduction were successfully performed.
