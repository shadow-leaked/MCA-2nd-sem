# %% [markdown]
# # Practical 3
# # Association Rule Mining using Apriori Algorithm

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules

# %%
data = {
    'Milk': [1,1,0,1],
    'Bread': [1,1,1,0],
    'Butter': [0,1,1,1]
}

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#    Milk  Bread  Butter
# 0     1      1       0
# 1     1      1       1
# 2     0      1       1
# 3     1      0       1

# %%
frequent_items = apriori(df, min_support=0.5, use_colnames=True)
# Out:
# d:\ai_agent\projects\Data Mining\venv\Lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:175: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %%
print("Frequent Itemsets")
print(frequent_items)
# Out:
# Frequent Itemsets
#    support                    itemsets
# 0     0.75           frozenset({Milk})
# 1     0.75          frozenset({Bread})
# 2     0.75         frozenset({Butter})
# 3     0.50    frozenset({Bread, Milk})
# 4     0.50   frozenset({Butter, Milk})
# 5     0.50  frozenset({Butter, Bread})

# %%
rules = association_rules(frequent_items, metric="confidence", min_threshold=0.5)

# %%
print("Association Rules")
print(rules[['antecedents', 'consequents', 'support', 'confidence']])
# Out:
# Association Rules
#            antecedents          consequents  support  confidence
# 0   frozenset({Bread})    frozenset({Milk})      0.5    0.666667
# 1    frozenset({Milk})   frozenset({Bread})      0.5    0.666667
# 2  frozenset({Butter})    frozenset({Milk})      0.5    0.666667
# 3    frozenset({Milk})  frozenset({Butter})      0.5    0.666667
# 4  frozenset({Butter})   frozenset({Bread})      0.5    0.666667
# 5   frozenset({Bread})  frozenset({Butter})      0.5    0.666667

# %% [markdown]
# ## Conclusion
#
# Apriori Algorithm successfully generated frequent itemsets and association rules.
